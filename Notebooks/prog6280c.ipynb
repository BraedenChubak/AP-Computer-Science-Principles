# %% [markdown]
# # Prog6280c: Video Game Sales

# %%
# %pip install pandas seaborn matplotlib -q
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Read dataset into dataframe
df = pd.read_csv('../data/video_game_sales.csv')
df.columns = df.columns.str.strip() # Get rid of trailing spaces in column names
df
# Out:
#       index  Rank                        Game Title Platform    Year  \
# 0         0     1                        Wii Sports      Wii  2006.0
# 1         1     2                 Super Mario Bros.      NES  1985.0
# 2         2     3                    Mario Kart Wii      Wii  2008.0
# 3         3     4                 Wii Sports Resort      Wii  2009.0
# 4         4     5                            Tetris       GB  1989.0
# ...     ...   ...                               ...      ...     ...
# 1902   1902  1903  Lizzie McGuire 2: Lizzie Diaries      GBA  2004.0
# 1903   1903  1904              Xenoblade Chronicles      Wii  2010.0
# 1904   1904  1905                     SingStar Abba      PS3  2008.0
# 1905   1905  1906    FIFA Soccer World Championship      PS2  2000.0
# 1906   1906  1907        WWE SmackDown vs. Raw 2011     X360  2010.0
#
#              Genre                    Publisher  North America  Europe  Japan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1907 non-null   int64
#  1   Rank           1907 non-null   int64
#  2   Game Title     1907 non-null   object
#  3   Platform       1907 non-null   object
#  4   Year           1878 non-null   float64
#  5   Genre          1907 non-null   object
#  6   Publisher      1905 non-null   object
#  7   North America  1907 non-null   float64
#  8   Europe         1907 non-null   float64
#  9   Japan          1907 non-null   float64
#  10  Rest of World  1907 non-null   float64
#  11  Global         1907 non-null   float64
#  12  Review         1907 non-null   float64
# dtypes: float64(7), int64(2), object(4)
# memory usage: 193.8+ KB

# %%
df.describe()
# Out:
#            index       Rank         Year  North America       Europe  \
# count  1907.0000  1907.0000  1878.000000    1907.000000  1907.000000
# mean    953.0000   954.0000  2003.766773       1.258789     0.706675
# std     550.6478   550.6478     5.895369       1.956560     1.148904
# min       0.0000     1.0000  1983.000000       0.000000     0.000000
# 25%     476.5000   477.5000  2000.000000       0.510000     0.230000
# 50%     953.0000   954.0000  2005.000000       0.810000     0.440000
# 75%    1429.5000  1430.5000  2008.000000       1.375000     0.810000
# max    1906.0000  1907.0000  2012.000000      40.430000    28.390000
#
#              Japan  Rest of World       Global       Review
# count  1907.000000    1907.000000  1907.000000  1907.000000
# mean      0.317493       0.206471     2.489240    79.038977
# std       0.724945       0.343093     3.563159    10.616899
# min       0.000000       0.000000     0.830000    30.500000
# ...

# %% [markdown]
# ## Task 1: Sales Analysis by Region

# %%
df[['North America', 'Europe', 'Japan', 'Rest of World']].sum().plot(kind='barh', color='slateblue')
df.dropna()
plt.title('Total Sales By Region')
plt.xlabel('Region')
plt.ylabel('Sales (Millions)')
plt.show()

# %% [markdown]
# North America sells more games than any other region, and it seems that not many games are sold outside of North America, Europe, and Japan.

# %%
sales_year = df.groupby('Year')['Global'].sum()
plt.figure(figsize=(10,6))
sales_year.plot(kind='line', marker='o', color='red')
plt.title('Global Video Game Sales by Year')
plt.xlabel('Year')
plt.ylabel('Global Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# Video Game Sales were relatively stagnant from 1985 to 1995, then steadily rose until their peak in 2008.  Video Game Sales have declined every year since.

# %%
platform_sales = df.groupby('Platform')['Global'].sum()
plt.title('Total Global Sales by Platform')
platform_sales.plot(kind='barh')
plt.xlabel('Sales (Millions)')
# Out:
# Text(0.5, 0, 'Sales (Millions)')

# %% [markdown]
# Most platforms range from 100 to 500 million sales, with some consoles performing below that, but the PS2 greatly outperforming every other console.

# %%
sns.scatterplot(x=df['Global'], y=df['Review'], hue=df['Genre'])
plt.title("Global Sales by Review Score")
# Out:
# Text(0.5, 1.0, 'Global Sales by Review Score')

# %% [markdown]
# In general, highly reviewed games get more global sales.  There are exceptions where moderately-reviewed games get a lot of sales however.

# %%
plt.figure(figsize=(8,18))
sns.heatmap(df.pivot_table(index='Publisher', columns='Year', values='Review'))
# Out:
# <Axes: xlabel='Year', ylabel='Publisher'>

# %% [markdown]
# The only publisher to release a game every year from 1983 to 2012 is Nintendo.  Some publishers release a game almost every year after a certain year, probably when they were created, while others only release a game once every few years.
